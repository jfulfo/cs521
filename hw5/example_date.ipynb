# %%
from syncode import Syncode

grammar = """ start: month " " day 
              
              day: /[1-9]/ | /[1-2][0-9]/ | /3[0-1]/
              
              month: "January" | "February" | "March" | "April" | "May" | "June" | "July" | "August" | "September" | "October" | "November" | "December"
"""

model_name = "microsoft/phi-2"

# Load the unconstrained original model
llm = Syncode(model = model_name, mode='original', max_new_tokens=20)

# Load the Syncode augmented model
syn_llm = Syncode(model = model_name, grammar=grammar, parse_output_only=True, max_new_tokens=20)
# Out:
# [2025-12-12 16:36:13,891-root] - Loading model microsoft/phi-2 with device:cuda, device_map:auto, torch_dtype:torch.bfloat16
# [2025-12-12 16:36:14,461-accelerate.utils.modeling] - We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# [2025-12-12 16:36:16,443-root] - Loading model microsoft/phi-2 with device:cuda, device_map:auto, torch_dtype:torch.bfloat16
# [2025-12-12 16:36:16,538-accelerate.utils.modeling] - We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# [2025-12-12 16:36:28,237-syncode.mask_store.mask_store] - Using cache: True and fsm path cache/mask_stores/CodeGenTokenizerFast/grammar_strict_1031476375_50257.pkl exist: False
# [2025-12-12 16:36:28,238-syncode.mask_store.mask_store] - Creating mask store for CodeGenTokenizerFast and custom, may take more than 10 minutes. Caching at /home/jamie/cs521/hw5/cache/mask_stores/CodeGenTokenizerFast/grammar_strict_1031476375_50257.pkl.
# [2025-12-12 16:36:28,481-syncode.mask_store.fsm_set] - 16 FSMs with 96 states initialized in 0.00 seconds
# [2025-12-12 16:36:28,482-syncode.mask_store.mask_store] - Ignore whitespace is False
# [2025-12-12 16:36:28,487-syncode.mask_store.mask_store] - Number of 2 length terminal sequences reduced from 256 to 15
# 100%|██████████| 96/96 [00:06<00:00, 14.65it/s]
# [2025-12-12 16:36:35,047-syncode.mask_store.mask_store] - Time taken to create mask store: 6.81 seconds

# %%
inp = "When is the US independence day?"

output = llm.infer(inp)[0]
print(f"LLM output:\n{repr(output)}\n")

output = syn_llm.infer(inp)[0]
print(f"Syncode augmented LLM output:\n{output}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# LLM output:
# '\nThe US Independence Day is celebrated on July 4th every year.\n\nWhat is the significance'
#
# Syncode augmented LLM output:
# July 4

# %%
inp = "When is the christmas day?"

output = llm.infer(inp)[0]
print(f"LLM output:\n{repr(output)}\n")

output = syn_llm.infer(inp)[0]
print(f"Syncode augmented LLM output:\n{output}")
# Out:
# LLM output:
# '\n\nA:\n\nYou can use the following code:\nimport java.util.Scan'
#
# Syncode augmented LLM output:
# December 25

# %%
inp = "When is the veterans day?"

output = llm.infer(inp)[0]
print(f"LLM output:\n{repr(output)}\n")

output = syn_llm.infer(inp)[0]
print(f"Syncode augmented LLM output:\n{output}")
# Out:
# LLM output:
# '\nThe date of the Veterans Day is November 11.\nWhat is the Veterans Day?\nThe'
#
# Syncode augmented LLM output:
# November 11
